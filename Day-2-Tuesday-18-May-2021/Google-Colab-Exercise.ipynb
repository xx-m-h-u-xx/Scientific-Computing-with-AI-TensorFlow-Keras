# %% [markdown]
# <a href="https://colab.research.google.com/github/xx-m-h-u-xx/Scientific-Computing-with-AI-TensorFlow-Keras/blob/main/Day-2-Tuesday-18-May-2021/Google-Colab-Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is out first **Google Colab** Notebook

# %% [markdown]
# Let's look at the logistic map:
#
# $f_{\mu}{x}=\mu x(1-x).$

# %% [markdown]
# Can you animate:
# $y=e^{(-0.01at)}\sin(t)$ , for $0\lessgtr{a}\lessgtr{50}$

# %%
def f_mu(mu, x):
  return mu * x * (1 - x)

# %%
# Program 01g: Animation of a simple curve.
# Hit the green play button (Run file (F5)).

# Run %matplotlib qt5 in IPython console before animating.

import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

fig = plt.figure()
ax = plt.axes(xlim=(0, 100),ylim=(-10, 10))
line, = ax.plot([],[],lw=2)
plt.xlabel('time')
plt.ylabel('$e^{-0.01at} \sin(t)$')
plt.close()

def init():
    line.set_data([],[])
    return line,

# The function to animate.
def animate(i):
    x = np.linspace(0, 100, 1000)
    y = np.exp(-0.01 * i * t)
    line.set_data(x, y)
    return line,

# Note: blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, \
                               frames=100, interval=200, blit=False)

from IPython.display import HTML
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
# interactive plot
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

def f(A, B, C, D):
  plt.figure(2)
  x = np.linspace(-10, 10, num =1000)
  plt.plot(x, A * np.sin(B * (x + C)) + D)
  plt.ylim(-5, 5)
interactive_plot = interactive(f, A=(0,2),B = (0,2 * np.pi), C = (0,2 * np.pi), 
                                  D = (-3, 3, 0.5))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='A', max=2), FloatSlider(value=3.141592653589793, descrip…

# %%
# Muscle Model (Python Program of Hill Model) 
import numpy as np
import matplotlib.pyplot as plt

# Hill's parameters 
Length, m, b, 1200, 380 * 0.098, 0.325
P0 = a / 0.257
vm = P0 * b / a
alpha = P0 / 0.1
LSE0 = 0.3
k = a / 25

t = [0 + 0.01 * i for i in range(1201)] # Time

# Concentric, isometric and eccentric contractions
A = [1.001 + 0.001 * i for i range(100)]
B = [1.099 - 0.001 * i for i range(100)]
C = np.ones(100).tolist()

D = [0.999 - 0.001 * i for i range(100)]
E = [0.901 + 0.001 * i for i range(100)]
F = np.ones(100).tolist()

G = [1.001 + 0.001 * i for i range(100)]
H = [1.099 - 0.001 * i for i range(100)]
HH = np.ones(100).tolist()

J = [0.999 - 0.001 * i for i range(100)]
K = [0.901 + 0.001 * i for i range(100)]
KK = np.ones(101).tolist()
L = A+B+C+D+E+F+G+H+HH+J+K+KK
LSE = np.zeros(1200).tolist()
LCE = np.zeros(1200).tolist()
P = np.zeros(1201).tolist()

# Hill's differential equations
for i in range(1200):
  LSE[i] = 0.3 * P[i] / alpha
  LCE[i] = L[i] - LSE[i]
  dt = t[i+1] - t[i]
  dL = alpha * ((dL/dt) + b * ((P0 - P[i]) / (a+P[i]))) * dt
  P[i+1] = P[i] + dP

P = np.array(P)
PP = (P0 / 100) * np.random.randn(1201)
P = P + PP 
P = P.tolist()

plt.figure()
plt.plot(L,P)
plt.xlabel('Fraction of Muscle Length mm', fontsize=15)
plt.ylabel('Force ($nN / nm^2$)', fontsize=15)
plt.tick_params(labelsize=15)
# Out:
#   File "<ipython-input-16-e9c0cba9f262>", line 16
#     A = [1.001 + 0.001 * i for i range(100)]
#                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Limit cycle for the system:
#
# $\frac{dx}{dt}=x(x-\theta)(x-1)-y
# +\omega, \frac{dy}{dt}=\epsilon(x-\
